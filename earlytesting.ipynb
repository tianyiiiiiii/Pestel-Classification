# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
import transformers
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler,TensorDataset
# from datasets import Dataset
from torch.utils.data import Dataset 
import torch
from torch.optim import AdamW
from transformers import get_scheduler
from tqdm.auto import tqdm
import evaluate
from torch.nn import CrossEntropyLoss
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
import os
import glob
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
# df = pd.read_csv("data/balancednewcategory.csv")
# df = pd.read_csv("data/5knewscategory.csv")
# df = pd.read_csv("data/100pernewscategory.csv")
df = pd.read_csv("data/400perMNDS.csv")
df.head()
# Out:
#    data_id                                                 id        date  \
# 0   202399  fortune--2019-02-26--Amazon Adds Former PepsiC...  2019-02-26
# 1   668391    theduran--2019-09-23--Pakistans Economic Crisis  2019-09-23
# 2  1064343  unian--2019-09-06--Reuters Oil rises set for w...  2019-09-06
# 3   308315  mediamattersforamerica--2019-04-29--New NRA Pr...  2019-04-29
# 4   494786  sottnet--2019-01-13--Saudi energy minister cla...  2019-01-13
#
#                    source                                              title  \
# 0                 fortune  Amazon Adds Former PepsiCo Chief Indra Nooyi t...
# 1                theduran                         Pakistan’s Economic Crisis
# 2                   unian  Reuters: Oil rises, set for weekly gain amid h...
# 3  mediamattersforamerica  New NRA President Carolyn Meadows chairs the b...
# 4                 sottnet  Saudi energy minister claims oil market on 'ri...
#
#                                                 text  \
# 0  Amazon has added former PepsiCo CEO Indra Nooy...
# 1  Pakistan is going through financial woes. The ...
# 2  Brent crude was up 17 cents, or 0.3%, at $61.1...
# 3  Carolyn Meadows, who is succeeding Oliver Nort...
# 4  Saudi Arabia's top energy official expects the...
#
#                       author  \
# 0               Erik Sherman
# 1         Serban V.C. Enache
# 2                        NaN
# 3  Media Matters for America
# 4                        NaN
#
#                                                  url  \
# 0  http://fortune.com/2019/02/26/amazon-board-ind...
# 1    https://theduran.com/pakistans-economic-crisis/
# 2  https://www.unian.info/economics/10675431-reut...
# 3  https://www.mediamatters.org/blog/2019/04/29/n...
# 4  https://www.sott.net/article/404819-Saudi-ener...
#
#                    published  published_utc  collection_utc  \
# 0  2019-02-26 14:40:17+00:00     1551210017      1567547264
# 1  2019-09-23 07:49:51+00:00     1569239391      1570222447
# 2  2019-09-06 06:00:00+00:00     1567764000      1569331139
# 3  2019-04-29 21:18:38+00:00     1556587118      1567541775
# 4  2019-01-13 16:03:45+00:00     1547413425      1567552737
#
#                 category_level_1      category_level_2 PESTEL_label
# 0  economy, business and finance  business information     Economic
# 1  economy, business and finance       economic sector     Economic
# 2  economy, business and finance   market and exchange     Economic
# 3  economy, business and finance  business information     Economic
# 4  economy, business and finance   market and exchange     Economic

# %%
# df["content"] = df["headline"] + " " + df["short_description"]
df["content"] = df["title"] + " " + df["text"]
df = df[['PESTEL_label', 'content']]
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'content'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[158], line 2
#       1 # df["content"] = df["headline"] + " " + df["short_description"]
# ----> 2 df["content"] = df["title"] + " " + df["content"]
#       3 df = df[['PESTEL_label', 'content']]
#       4 df.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'content'

# %%
# convert content to string and handle NaN
df['content'] = df['content'].apply(lambda x: '' if pd.isna(x) else str(x))

# %%
def clean_text(text):
    text = text.replace('\n', ' ').strip()
    return text

df['content'] = df['content'].apply(clean_text)

# %%
# test set 20%
train_val_df, test_df = train_test_split(
    df, test_size=0.2, stratify=df['PESTEL_label'], random_state=42
)

# train set 70%, val set 10%
train_df, val_df = train_test_split(
    train_val_df, test_size=0.125, stratify=train_val_df['PESTEL_label'], random_state=42
)

# %%
class NewsDataset(Dataset):
    def __init__(self, data, tokenizer, max_len, pestel_to_idx):
        self.df = data
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.pestel_to_idx = pestel_to_idx

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        row = self.df.iloc[index] 
        content = row['content']
        label = row['PESTEL_label']

        inputs = self.tokenizer.encode_plus(
            content,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            return_token_type_ids=True,
            truncation=True
        )

        return {
            'ids': torch.tensor(inputs['input_ids'], dtype=torch.long),
            'mask': torch.tensor(inputs['attention_mask'], dtype=torch.long),
            'targets': torch.tensor(self.pestel_to_idx[label], dtype=torch.long)
        }
        
pestel_to_idx = {
    "Political": 0,
    "Economic": 1,
    "Social": 2,
    "Technological": 3,
    "Environmental": 4,
    "Legal": 5
}

# %%
class_names = ["Political", "Economic", "Social", "Technological", "Environmental", "Legal"]

# %%
tokenizer = transformers.DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
distilbert_model = transformers.DistilBertModel.from_pretrained('distilbert-base-uncased')

# %%
class PestelClassifier(torch.nn.Module):
    def __init__(self, distilbert, num_classes):
        super(PestelClassifier, self).__init__()
        self.distilbert = distilbert
        self.dropout = torch.nn.Dropout(0.3)
        self.output = torch.nn.Linear(768, num_classes)
        
        # self.classifier = torch.nn.Sequential(
        #     torch.nn.Linear(768, 256),
        #     torch.nn.ReLU(),
        #     torch.nn.Dropout(0.5),
        #     torch.nn.Linear(256, num_classes)
        # )

    def forward(self, ids, mask):
        output = self.distilbert(ids, attention_mask=mask)
        output = self.dropout(output[0][:, 0, :])  # CLS token
        output = self.output(output)
        return output
    
        # output = self.distilbert(ids, attention_mask=mask).last_hidden_state[:, 0, :]
        # output = self.classifier(output)
        # return output

# %%
def evaluate_bert_model(model, data_loader, loss_function, device, set_name="Test"):
    model.eval()
    total_loss = 0
    all_preds = []
    all_targets = []
    loop = tqdm(data_loader, desc=f"{set_name} Evaluation")

    with torch.no_grad():
        for batch in loop:
            ids = batch['ids'].to(device)
            mask = batch['mask'].to(device)
            targets = batch['targets'].to(device)

            outputs = model(ids, mask)
            loss = loss_function(outputs, targets)
            total_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().tolist())
            all_targets.extend(targets.cpu().tolist())

            loop.set_postfix(loss=loss.item())

    avg_loss = total_loss / len(data_loader)
    accuracy = accuracy_score(all_targets, all_preds)
    precision = precision_score(all_targets, all_preds, average='macro', zero_division=0)
    recall = recall_score(all_targets, all_preds, average='macro', zero_division=0)
    f1 = f1_score(all_targets, all_preds, average='macro', zero_division=0)

    print(f"{set_name} Loss: {avg_loss:.4f} | Acc: {accuracy*100:.2f}% | P: {precision:.4f} | R: {recall:.4f} | F1: {f1:.4f}")

    return avg_loss, accuracy, precision, recall, f1, all_preds, all_targets

# %%
num_classes = 6  # For PESTEL
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = PestelClassifier(distilbert_model, num_classes)
model.to(device)
# Out:
# PestelClassifier(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.3, inplace=False)
#   (output): Linear(in_features=768, out_features=6, bias=True)
# )

# %%
EPOCHS = 100
LEARNING_RATE = 5e-6
MAX_LEN = 512 # truncated as avg 4000 char per article is around 1000 tokens -> 512 is limit of DistilBERT
BATCH_SIZE = 16

train_set = NewsDataset(train_df, tokenizer, MAX_LEN, pestel_to_idx)
val_set = NewsDataset(val_df, tokenizer, MAX_LEN, pestel_to_idx)
test_set = NewsDataset(test_df, tokenizer, MAX_LEN, pestel_to_idx)

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE,  weight_decay=0.01)
loss_function = torch.nn.CrossEntropyLoss()

# %%
checkpoint = torch.load("./checkpoints_mnds_400per/best_model.pt", map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device)

test_loss, test_accuracy, precision, recall, f1, preds, targets = evaluate_bert_model(
    model=model,
    data_loader=test_loader,
    loss_function=loss_function,
    device=device,
    set_name="Test"
)

print(f"Final Test Accuracy: {test_accuracy * 100:.2f}% | Test Loss: {test_loss:.4f}")
# Out:
# Test Evaluation: 100%|██████████| 30/30 [00:39<00:00,  1.30s/it, loss=0.0704]
# Test Loss: 0.5206 | Acc: 85.83% | P: 0.8646 | R: 0.8583 | F1: 0.8583
# Final Test Accuracy: 85.83% | Test Loss: 0.5206

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(targets, preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(xticks_rotation=45)
plt.title("Confusion Matrix on Test Set")
plt.show()

cm = confusion_matrix(targets, preds)
cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] 
cm_display = np.round(cm_percent, 5)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_display, display_labels=class_names)
disp.plot(cmap='viridis', xticks_rotation=45)
plt.title("Confusion Matrix on Test Set (Percentage)")
plt.show()

# %%
test_df = test_df.reset_index(drop=True)  # to align with test_set order

for i in range(len(preds)):
    if preds[i] != targets[i]:
        print(f"TEXT: {test_df.loc[i, 'content'][:100]}...")
        print(f"TRUE: {class_names[targets[i]]} | PREDICTED: {class_names[preds[i]]}")
        print('-' * 80)
# Out:
# TEXT: PENTAGON: Moscow outgunning USA in race for global influence... The U.S. is ill-equipped to counter ...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Toxic Masculinity Attention boys: bullying, homophobia, sexual harassment and abuse are all your fau...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Trump’s Tariffs Were Supposed to Ding China, But the U.S. Economy Is Getting Hit 2.5x Harder Faceboo...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Economist Who Predicted 2008 Economic Crisis Warns of 2020 Recession Risk Economist Nouriel Roubini,...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Video: Man Fires Shots into Street From Assault Rifle Over Family Conflict in Russia's Koltushi The ...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Bacteria may travel around the world using "air bridges," explaining how superbugs share genes (Natu...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Conspiracy Theories Can’t Be Stopped Shortly before killing 50 people at two New Zealand mosques, th...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Los Angeles Teachers Prepare for Strike More than 33,000 teachers in the Los Angeles Unified School ...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Germans Rush to Buy Gold as Draft Bill Threatens to Restrict Purchases Reports have emerged depictin...
# TRUE: Legal | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: China’s ambassador accuses Canada of ‘white supremacy’ in Huawei CFO arrest China’s ambassador to Ca...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: The Drilldown: Report finds climate change most underreported humanitarian crisis Food shortages bor...
# TRUE: Political | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Researchers find plastic-eating microbe that can solve our ocean's plastic problem (Natural News) Ev...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: California Democrats are one step closer to forcing college health clinics to provide 'abortion pill...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Are Western Doctors Compelled To Support If we take a broad overview of the structure of conventiona...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Immigration court backlogs compound as shutdown enters fourth week Dozens of immigration courts rema...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: UK to introduce porn age-checks in July An age-check scheme designed to stop under-18s viewing porno...
# TRUE: Legal | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: FLASHBACK:  Prosecutors who covered up Mass. drug lab scandal now face bar discipline, civil rights ...
# TRUE: Technological | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Poles at the polls: Five things to know Warsaw, Poland - Sunday's vote here is widely considered a l...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Gilets jaunes: How much anti-Semitism is beneath the yellow vests? The French far-right leader, Mari...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Glasgow gang who forced women into slavery and prostitution sold victim for £10k outside Primark A g...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: State Takes Child from Parents, Forces Him to Take Chemo for Treating Cancer With Cannabis Parents o...
# TRUE: Legal | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Clashes Erupt In Georgia’s Pankisi Gorge Over Construction Of Hydropower Plant Clashes broke out on ...
# TRUE: Environmental | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: New State Regulations Force a California Charity for the Homeless to Close Shop For the past four ye...
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Venezuela's Guaido lays out broad vision for the country Venezuela's self-proclaimed interim preside...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Moscow rejects FBI chief’s election meddling accusations, says senior diplomat MOSCOW, July 24. /TAS...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Official Secrets: Priti Patel’s Early War on Whistleblowers As British ambassador to the US Kim Darr...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: The Russians appear to be crashing Donald Trump’s meeting with Kim Jong Un “President” Donald Trump ...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: ICE Raids Texas Technology Company, Arrests 280 On Immigration Violations Immigration and Customs En...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Twelve ways to break your children’s screen addiction as technology and gaming disrupts sleep POWER ...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Newt Gingrich: Huawei Charges Are More Than An Indictment, China Is Threatening Our National Securit...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Oxfam: World's richest 26 own same wealth as poorest half The world's 26 richest people own the same...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: The poor bloody infantry: why people join political parties Footsoldiers: Political Party Membership...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: The Unwanted: The Secret Windrush Files review – who could feel proud of Britain after this? As the ...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Amazing: Texas A&M introduces program for students with disabilities People with disabilities have a...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Abortion rights campaigners flood the streets of Buenos Aires Thousands of women rallied in the Arge...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Kentucky Governor Signs “Constitutional Carry” Bill into Law Kentucky Gov. Matt Bevin has signed a b...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Deep Dive: FTC Negotiating Multi-Billion Dollar Fine For Facebook’s Privacy Scandals; Violating 2011...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: The Latest: Fiat Chrysler, auto union agree tentative deal The Latest on contract talks between the ...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Quillette, Ben Shapiro, and the Myth of Conservative ‘Facts’ “Today's culture wars are framed as a c...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: "We Can't Afford to Wait for the DNC": Why Black Lawmakers Organized an Environmental Justice Forum ...
# TRUE: Environmental | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Mankind Has Lost the Art of Map Reading The inventor of GPS has lamented that people are unable to r...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Pro-Vaccine Internet Trolls May Be Trained Government Agents Glenn Greenwald, a journalist, constitu...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Mexican immigrant fights for DACA as court ruling nears A Mexican immigrant fighting President Donal...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Can solar power shake up the energy market? The classical Greek philosopher Socrates believed the id...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Washington state deals setback to massive methanol plant Washington state dealt a setback Friday to ...
# TRUE: Economic | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Ask Amy: In-laws tag along to wedding weekend Dear Amy: Our older son and his wife are bringing her ...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Dutch cardinal: It would be a &#8216;scandal&#8217; for a priest to be present at an assisted suicid...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Majority of Economists Predict Recession Before 2021 Washington Post: “The outlook reflects growing ...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Climate change is already exacerbating global economic inequality Global economic inequality has bee...
# TRUE: Environmental | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Catalan 'rebellion' trial puts Spain's courts to the test Writing from his prison cell, the former v...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: What’s Fact and What’s Fiction in <em>The Two Popes</em> In The Two Popes, director Fernando Meirell...
# TRUE: Political | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Trump Tweets In Favor of Risky and Harmful 5G and 6G Tech Despite Opposition from Security Experts, ...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Analyst predicts U.S. economic growth, but at a slower pace in 2019 and ’20 The U.S. stock market ju...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Moscow, St. Petersburg Become Cheaper for Expats, Ranking Says Moscow placed 27th and St. Petersburg...
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Tribunal rules Christian values clash with UK values of "human dignity" and "fundamental rights of o...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: North Korea's Kim ends China visit as Trump summit looms North Korean leader Kim Jong Un has left Be...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Citizenship Amendment Act: India PM Modi appeals for calm as protests grow India's Prime Minister Na...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Islam and Orthodox Christianity Have the Same Values, Putin Says The conference, titled "Orthodoxy a...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Manafort accused of lying about sharing polling data with Russian A new court filing says that US Pr...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: China’s Xi says Beijing wants trade deal, can ‘fight back’ Chinese President Xi Jinping said Friday ...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Physician, Father and Caretaker of 29 Year Old Autistic Man Found Brutally Murdered "One family memb...
# TRUE: Legal | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Macron announces crackdown on anti-Semitism in France French President Emmanuel Macron has announced...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Lord William Wallace writes…Fighting for liberal values Putin has paid us a compliment.  He’s define...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Addiction Clinics Market Unproven Infusion Treatments To Desperate Patients Jason was hallucinating....
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Novartis Bets Big on Cholesterol Drug With $9.7 Billion Buyout of Medicines Co. There Has Been an In...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: UK physician ethics committee chair resigns over assisted suicide change The chairman of the ethics ...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: How to leave the United Kingdom Boris Johnson’s Conservatives have achieved their best election resu...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: House Passes Bill Opening Backdoor Immigration Route for Wealthy Chinese The House quietly passed a ...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
