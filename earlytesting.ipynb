# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
import transformers
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler,TensorDataset
# from datasets import Dataset
from torch.utils.data import Dataset 
import torch
from torch.optim import AdamW
from transformers import get_scheduler
from tqdm.auto import tqdm
import evaluate
from torch.nn import CrossEntropyLoss
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import os
import glob
import torch
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/5knewscategory.csv")
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/mortgage-...
# 1  https://www.huffingtonpost.com/entry/women-in-...
# 2  https://www.huffingtonpost.com/entry/like-athl...
# 3  https://www.huffingtonpost.com/entry/donald-tr...
# 4  https://www.huffingtonpost.com/entry/grocery-c...
#
#                                             headline  category  \
# 0  Mortgage Deal Reached In 2008 Shows Pitfalls T...  BUSINESS
# 1  Women in Business: Kate O'Brien Minson, Presid...  BUSINESS
# 2  Like Athletes, Business Owners Need to Learn F...  BUSINESS
# 3  Trump Could Trigger The Longest Recession Sinc...  BUSINESS
# 4  Grocery Chains Made A Promise To The First Lad...  BUSINESS
#
#                                    short_description  \
# 0  The Obama administration, which is pushing sta...
# 1  Kate has lived and breathed the therapeutic ap...
# 2  Business owners and top executives can also "w...
# 3                                             Yikes.
# 4  An AP investigation found that major grocers o...
#
#                                              authors        date PESTEL_label
# 0                                       Loren Berlin  2012-02-05     Economic
# 1  Laura Dunn, ContributorSocial Media and Commun...  2015-04-25     Economic
# 2  Mary Ellen Biery, ContributorResearch Speciali...  2015-01-19     Economic
# 3                                          Ben Walsh  2016-06-27     Economic
# 4                                 Mike Schneider, AP  2015-12-07     Economic

# %%
df["content"] = df["headline"] + " " + df["short_description"]
df = df[['PESTEL_label', 'content']]
df.head()
# Out:
#   PESTEL_label                                            content
# 0     Economic  Mortgage Deal Reached In 2008 Shows Pitfalls T...
# 1     Economic  Women in Business: Kate O'Brien Minson, Presid...
# 2     Economic  Like Athletes, Business Owners Need to Learn F...
# 3     Economic  Trump Could Trigger The Longest Recession Sinc...
# 4     Economic  Grocery Chains Made A Promise To The First Lad...

# %%
# convert content to string and handle NaN
df['content'] = df['content'].apply(lambda x: '' if pd.isna(x) else str(x))

# %%
def clean_text(text):
    text = text.replace('\n', ' ').strip()
    return text

df['content'] = df['content'].apply(clean_text)

# %%
# test set 20%
train_val_df, test_df = train_test_split(
    df, test_size=0.2, stratify=df['PESTEL_label'], random_state=42
)

# train set 70%, val set 10%
train_df, val_df = train_test_split(
    train_val_df, test_size=0.125, stratify=train_val_df['PESTEL_label'], random_state=42
)

# %%
class NewsDataset(Dataset):
    def __init__(self, data, tokenizer, max_len, pestel_to_idx):
        self.df = data
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.pestel_to_idx = pestel_to_idx

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        row = self.df.iloc[index] 
        content = row['content']
        label = row['PESTEL_label']

        inputs = self.tokenizer.encode_plus(
            content,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            return_token_type_ids=True,
            truncation=True
        )

        return {
            'ids': torch.tensor(inputs['input_ids'], dtype=torch.long),
            'mask': torch.tensor(inputs['attention_mask'], dtype=torch.long),
            'targets': torch.tensor(self.pestel_to_idx[label], dtype=torch.long)
        }
        
pestel_to_idx = {
    "Political": 0,
    "Economic": 1,
    "Social": 2,
    "Technological": 3,
    "Environmental": 4,
    "Legal": 5
}

# %%
class_names = ["Political", "Economic", "Social", "Technological", "Environmental", "Legal"]

# %%
tokenizer = transformers.DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
distilbert_model = transformers.DistilBertModel.from_pretrained('distilbert-base-uncased')

# %%
class PestelClassifier(torch.nn.Module):
    def __init__(self, distilbert, num_classes):
        super(PestelClassifier, self).__init__()
        self.distilbert = distilbert
        self.dropout = torch.nn.Dropout(0.3)
        self.output = torch.nn.Linear(768, num_classes)
        
        self.classifier = torch.nn.Sequential(
            torch.nn.Linear(768, 256),
            torch.nn.ReLU(),
            torch.nn.Dropout(0.3),
            torch.nn.Linear(256, num_classes)
        )


    def forward(self, ids, mask):
        # output = self.distilbert(ids, attention_mask=mask)
        # output = self.dropout(output[0][:, 0, :])  # CLS token
        # output = self.output(output)
        output = self.distilbert(ids, attention_mask=mask).last_hidden_state[:, 0, :]
        output = self.classifier(output)
        return output

# %%
def evaluate_bert_model(model, data_loader, loss_function, device, set_name="Test"):
    model.eval()
    total_loss = 0
    all_preds = []
    all_targets = []
    loop = tqdm(data_loader, desc=f"{set_name} Evaluation")

    with torch.no_grad():
        for batch in loop:
            ids = batch['ids'].to(device)
            mask = batch['mask'].to(device)
            targets = batch['targets'].to(device)

            outputs = model(ids, mask)
            loss = loss_function(outputs, targets)
            total_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().tolist())
            all_targets.extend(targets.cpu().tolist())

            loop.set_postfix(loss=loss.item())

    avg_loss = total_loss / len(data_loader)
    accuracy = accuracy_score(all_targets, all_preds)
    precision = precision_score(all_targets, all_preds, average='macro', zero_division=0)
    recall = recall_score(all_targets, all_preds, average='macro', zero_division=0)
    f1 = f1_score(all_targets, all_preds, average='macro', zero_division=0)

    print(f"{set_name} Loss: {avg_loss:.4f} | Acc: {accuracy*100:.2f}% | P: {precision:.4f} | R: {recall:.4f} | F1: {f1:.4f}")

    return avg_loss, accuracy, precision, recall, f1, all_preds, all_targets

# %%
num_classes = 6  # For PESTEL
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = PestelClassifier(distilbert_model, num_classes)
model.to(device)
# Out:
# PestelClassifier(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.3, inplace=False)
#   (output): Linear(in_features=768, out_features=6, bias=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=768, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=256, out_features=6, bias=True)
#   )
# )

# %%
EPOCHS = 50
LEARNING_RATE = 1e-5 
MAX_LEN = 128 
BATCH_SIZE = 32 

train_set = NewsDataset(train_df, tokenizer, MAX_LEN, pestel_to_idx)
val_set = NewsDataset(val_df, tokenizer, MAX_LEN, pestel_to_idx)
test_set = NewsDataset(test_df, tokenizer, MAX_LEN, pestel_to_idx)

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE,  weight_decay=0.01)
loss_function = torch.nn.CrossEntropyLoss()

# %%
checkpoint = torch.load("./checkpoints_5k/best_model.pt", map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device)

test_loss, test_accuracy, precision, recall, f1, preds, targets = evaluate_bert_model(
    model=model,
    data_loader=test_loader,
    loss_function=loss_function,
    device=device,
    set_name="Test"
)

print(f"Final Test Accuracy: {test_accuracy * 100:.2f}% | Test Loss: {test_loss:.4f}")
# Out:
# Test Evaluation: 100%|██████████| 105/105 [01:16<00:00,  1.38it/s, loss=0.897]
# Test Loss: 0.6066 | Acc: 80.06% | P: 0.8009 | R: 0.8006 | F1: 0.8005
# Final Test Accuracy: 80.06% | Test Loss: 0.6066

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(targets, preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(xticks_rotation=45)
plt.title("Confusion Matrix on Test Set")
plt.show()

# %%
test_df = test_df.reset_index(drop=True)  # to align with test_set order

for i in range(len(preds)):
    if preds[i] != targets[i]:
        print(f"TEXT: {test_df.loc[i, 'content'][:100]}...")
        print(f"TRUE: {class_names[targets[i]]} | PREDICTED: {class_names[preds[i]]}")
        print('-' * 80)
# Out:
# TEXT: Why Are Panda Babies So Small? Panda Researcher Fingers Bamboo (UPDATED) Itty bittiness is "definite...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: 2017 Saw A Record High Of Insurance Claims Due To Natural Disasters They amount to about $135 billio...
# TRUE: Environmental | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Income Inequality - Getting Yourself on the Right Side of the Equation We were all told from the tim...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: No, The Powerball Jackpot Isn't Enough To Give Everyone $4.3 Million Dividing up the winnings would ...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Facebook To Build Apartments In Silicon Valley But they're not for Facebook employees....
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Richard Dawkins Accuses Ahmed Mohamed Of Committing 'Fraud' Dawkins thinks the teenager had a plan t...
# TRUE: Technological | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Reflecting on 50 Years of the Civil Rights Act of 1964 Today, July 2, 2014, marks the 50th anniversa...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Michael Lawson's Straw Home Offers Roadmap For Ditching The Heating Bill Take a look at the home in ...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: The Time For Single-Payer Is Now When presented with an unexpected up-or-down vote on single-payer h...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Cerebral Palsy Didn't Stop This College Junior. Obamacare Repeal Might. Here's what cutting Medicaid...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Why Paul Krugman Should Be The New Treasury Secretary President Obama hasn't picked a treasury secre...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Twitter Is Ready To Address Online Abuse, Now That The Election Is Over This year saw a surge in tro...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: 3 New York City Jewish Organizations Received Threats This Week A center for the aging, a children's...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Marijuana Users Feel Less Dedicated To Work, Shocking Report Finds "It's the higher-level use that's...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: One Simple Thing You Can Do To Help Create A Kinder World In The New Year Worried about the state of...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: George Zimmerman: God Is The 'Only Judge That I Have To Answer To' "I have a lot of people saying th...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: What Is Frankincense? Christmas Resin Is Dried Sap Of Boswellia Sacra Tree By: Douglas Main, Life's ...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: States Step Up To Help Traumatized Veterans Veterans who served after 9/11 experienced a range of tr...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: My Conversation With Simon Sinek (VIDEO) By ourselves we can make a ripple in the pond and a differe...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: The Ultimate Moving Guide for First-Time Renters There are many details to consider after you've suc...
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Chicago To Pay $4.9 Million To Family Of Man Dragged In Handcuffs Philip Coleman died at a hospital ...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Trump Administration's Rollback Of Clean Power Plan Rolls Over Our Economy, Jobs This is good news f...
# TRUE: Environmental | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Nissan Launches Anti-Union Blitz Ahead Of Pivotal UAW Election As the United Auto Workers seek a foo...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Shutdown Leaves Connecticut’s ‘Coast Guard City’ Reeling: 'I Never Expected This' The government shu...
# TRUE: Political | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Open Letter To The DAPL Executives Dear Lee Hanse, Glenn Emery and Cliff Waters,  My name is Sage Is...
# TRUE: Environmental | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Cincinnati Judge Drops Charges Against Officer Who Killed Motorist Samuel DuBose Raymond Tensing, wh...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Facebook Profit Soars, Stock Hits All-Time High Facebook now has 8 billion video views each day, up ...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Spilled Coffee: Mathematical Model For Sloshing Beverage Addresses Cup Design, Walking Speed "This i...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: James Holmes Trial: Judge William Sylvester Must Balance Fairness With Public Transparency "You don'...
# TRUE: Legal | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: eBay Bans Confederate Flags The website called it a "symbol of divisiveness and racism."...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: New (And Very Cute) 'Chocolate Frog' Species Identified By Scientists The little frog, Litoria mira,...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Don't Let This Pile Of Pasta Fool You.. It's Alive! The "flying spaghetti monster" is actually a com...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Cancer Survivor Tells Paul Ryan: 'I'd Be Dead' Without Obamacare “Because of the Affordable Care Act...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: If David Attenborough Could Be Any Animal, Here's What He'd Pick It seems like he's a little conflic...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: MONDAY: Major Heads To Roll At Twitter The company also reportedly plans to add two new board member...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: 'Cocoon House' Features Organic, Eco-Friendly Design [PHOTOS] But Planning Korea isn’t alone in its ...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Being Comfortable With Fear Tami Simon, Founder and CEO of Sounds True, shares her daily experience ...
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: A Review of 'American Sniper' His steely, icy demeanor gave Chris Kyle a steady aim, but didn't prot...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: As Ice Melts, Dangerous Diseases From The Past Could Rise Again One more serious thing to worry abou...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Chipotle Tweaks Cooking Methods After E. Coli Outbreak "When you're given a project like this, you l...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Thinking Fast and Slow and Poorly and Well The world is full of strange behavior. It is natural to t...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Of Course Sean Spicer's Goodbye Email Contained A Typo "Wouldn't be authentic Spicer without that ty...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Big Wave Surfer Breaks His Back In Harrowing Wipeout On Video "A whole world of pain happened," says...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Manufacturing Lies Donald Trump promises to make American manufacturing great again. Yet all of his ...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Why Utah's Nonsensical New Abortion Bill Is So Bad For Women Mandating anesthesia isn't about protec...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Northern Lights: Sweden's Night Sky Swirls With Color In Amazing Aurora Borealis Video April Auroras...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: What If Your Performance Depended On Making People Smile? What if your class grade depended on makin...
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Equifax Says Another 2.4 Million Customers Hit By Data Breach In 2017 The company's shares were down...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Yik Yak Is Now Allowing Users To Post Photos The company warns people against posting things they wo...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Everything You Need To Know Before You Try Trail Running It's fall, the light is pretty, and the air...
# TRUE: Social | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: 8 Poisonous Foods We Commonly Eat One of the great perks of being around during this phase of human ...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: John Legend Clears Up Some Confusion For Trump Jr.: Your Father Is Racist John Legend calls a spade ...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Minnesota Realizes 'FMUSLMS' Vanity Plate Maybe Isn't Such A Hot Idea The driver's alternative reque...
# TRUE: Legal | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: How two guys from Stanford built the 'iPhone of vaporizers' Josh, a banker at a hedge fund in Manhat...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: 'How David Beats Goliath': A Trial Lawyer's Guide to Financial Management If you don't have experien...
# TRUE: Legal | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Hip Coffee Chains Are Selling Out, And That's OK Coffee snobs are worried, but they shouldn't be....
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Here's A Sign The 'Pokémon Go' Craze Can't Last Forever Has the Nintendo stock Pika-peaked?...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Miss Puerto Rico Suspended For Anti-Muslim Comments On Twitter "Her words do not represent the integ...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: A 'License to Kill'? 6 Million Lives at Stake Every Year If Philip Morris wins its case against Urug...
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Teen Vogue Writer Twists Knife After Taking Down Tucker Carlson "You’re actually being a partisan ha...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Lyme Disease Cases Are Rising In The Midwest Ticks and tick-borne diseases will probably keep spread...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Violence And Threats Toward Abortion Clinics Nearly Doubled After Planned Parenthood Videos One doct...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Mike Pence Says Disney Made 'Mulan' To Promote Women In Combat It was "obviously" the hope of a "mis...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Hey, They Are Stretching the Truth Way Too Far I was struck by what came out of the Troika this week...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Here's What To Know About The Bill Cosby Sexual Assault Retrial The comedian's sexual assault retria...
# TRUE: Legal | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Mining Companies Pay Far Less Than They Should For Taxpayer-Owned Coal Leases on federal land ignore...
# TRUE: Economic | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: The Surprising Benefit Of Going Through Hard Times Psychologists studying post-traumatic growth find...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: The Carnivore Way: All Who Wander Are Not Lost Obstacles to this basic need to roam, such as human d...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: 16 Handles Apologizes For Tasteless ‘Grab ‘Em By The Fro-Yo’ Ad Ew....
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: What Does Trayvon Martin and Sanford, Fla. Say About Our Nation Today? Yes, today, we may all be Tra...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Reflections on the Mediterranean Refugee Crisis From one end of the globe to the other, "have-nots" ...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Social Entrepreneurship Is the Ultimate Solution to Global Crises Now, we need more people to become...
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: The Historical Context of the Ferguson Riots What is happening in Ferguson is a result of the unfini...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Higher Education Group Roiled By Sexual Assault Claim Against Board Member The organization trains a...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Sexual Assault Survivors Gather Outside Fox News To Demand Bill O'Reilly Be Fired “Bill’s a good guy...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Jurors Could Be Swayed By That $6.4 Million For Freddie Gray’s Family But how the settlement might a...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Breaking Up With Apple After Living Together For 32 Years I thought we would grow old and die togeth...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Congratulations To Federal Inmate 06290-177 Jared Kushner ...and Anthony Weiner's new divorce lawyer...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: These Photos Of A Frozen Niagara Falls Are Pure Icy Magic Looks like Elsa's been here....
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Elon Musk's Tesla, SpaceX Join Companies Opposing Donald Trump's Immigration Order So far, there are...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Oil Losing Grip On Transport Industry Market, Report Claims LONDON, Oct 8 (Reuters) - - The transpor...
# TRUE: Environmental | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: What A Year This Month Has Been All of these things really happened in March 2018....
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: The Days of Our Lives, One Day at a Time Unfortunately, CBT is not readily available to everyone who...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Push for Progress: Children Cannot Wait So many children have lost ground as the trumped-up fear of ...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: More Equality And Dinosaurs: People Share How They'd Change The World "I want to change, like to hap...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Let’s Reduce Loss Of Life From Irma Every effort must be made in the coming days to ensure that warn...
# TRUE: Social | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Red Lipstick Gets Waitresses Big Tips From Men, Study Shows The researchers, Nicolas Guéguen and Cél...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: We Made Cribs Safer For Our Babies, Now What About Guns? As a nation, we must find ways to decrease ...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Changing How We Study Political Divisions Just Might Help Us Heal Them Our democracy may depend on i...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Climate Change Made Hurricane Harvey Worse, Scientists Say Rain associated with the lethal storm was...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Jimmy John's To Get Rid Of Controversial Noncompete Agreements In New York Go ahead, make sandwiches...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Protecting Families on Maternity Leave From Banks Refusing Loans Is a Victory for Fair Housing When ...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Passion If you're thinking of starting a restaurant, you need to sit down and ask yourself: "Do I re...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: How Much Gold Is In An Oscar Statuette? At tonight's Oscars we'll no doubt see some familiar faces w...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Vermont Leads GMO Labeling I honor Vermont's lawmakers and their bravery in raising the bar on human...
# TRUE: Political | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: USDA Says Paul LePage's Food Stamp Freakout Will Harm Children The governor of Maine threatened to d...
# TRUE: Political | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: 3 Genetics Tests To Improve Prenatal Screening This article is authored by the Mayo Clinic Center fo...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: New Orleans Gun Vigil Brings Together Grieving Moms, City Mayor (PHOTOS) "This year is the first yea...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Here's What Sex Ed Looks Like In California Everything you want to know about sex education in Calif...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: This Cafe Doesn't Have Pumpkin Spice, But It Does Have Puppies With cat cafes as popular as they are...
# TRUE: Environmental | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: The Health Effects Of Hormone-Altering Chemicals In Everyday Products Researchers discuss the latest...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Lawyers Explain What The Restaurant Industry Needs To Do To Protect Women And all of its employees, ...
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: How Obama Is ‘Trump-Proofing’ His Climate Pact In a roomful of oil and gas executives in North Dakot...
# TRUE: Political | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: The Top Outdoor Trends Of 2014 (PHOTOS) The American Society of Landscape Architects recently releas...
# TRUE: Social | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Protests Erupt In 'Last Stand' Against Dakota Access Pipeline “As much as this is an ecological cris...
# TRUE: Political | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: San Juan Mayor Says Trump Made Hurricane Maria Recovery About Himself "The federal government didn’t...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Lizards Hatch From Their Eggs Prematurely To Escape Danger, Study Suggests (VIDEO) There may be a do...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Trayvon Martin Shooting: Voice Experts Claim Cries Heard On 911 Call Were Not George Zimmerman's "I ...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Meetings in Wonderland Too often, we embark on the journey like Alice in Wonderland, with only a vag...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: 'Be Like Mike' on the Court -- and Bill James in the Classroom A generation ago, young players acros...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Gun Stocks Climb After Las Vegas Shooting Heightened fear after mass shootings often leads to more g...
# TRUE: Economic | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: 12 Ways to Drive More Readers to Your Content So, you've built a blog, invested a grand amount of ti...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Syrian Refugees In Jordan Can Now Scan Their Eyes To Pay For Groceries The technology aims to makes ...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: 18 Habits Of Highly Creative People Great artists, writers and innovators may have "messier minds."...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Kansas City Is Becoming a Mecca for Big Technology Names Kansas City will continue to be a catalyst ...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: I Don't Care About Autism Have I offended you yet? Have you already started crafting a nasty comment...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Petition Wants A Statue Of Missy Elliott To Replace A Confederate Monument "Together we can put whit...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: John Milton Merritt Allegedly Stole $300,000 From Four Orphan Girls Last Friday, Attorney John Milto...
# TRUE: Economic | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Jennifer McCarthy Releases 911 Call After Space Alien, Vagina Gun Debacle (UPDATE) Paleologo and dep...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Don't Count On 'Me Too' To Sway The Bill Cosby Jury The Me Too movement has launched a national disc...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Police Bet On Rare 'Pokemon Go' Character To Catch Fugitives Will the prospect of hooking a Charizar...
# TRUE: Legal | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Belvedere Vodka Ad Under Fire For Rape Implications "This is the most awful piece of promotional mat...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Helping a Person Live Like They Were Dying Lori sought a medical solution to help her lose weight an...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: World's Oldest Wild Bird Hatches Yet Another Chick Scientists call her "an iconic symbol of inspirat...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Officials Appalled By What's Inside These Crates Last week, officials at the Laos border stopped a s...
# TRUE: Environmental | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: NYC Names Historic Hotel The Source Of Deadly Legionnaires' Outbreak The rooftop air-conditioning un...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Will eBay Give Out ALEC Coal This Holiday Season? This holiday season, eBay's incoming CEO Devin Wen...
# TRUE: Environmental | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Mesmerizing Deep Ocean 'Symphony' Finally Identified The strange "Star Wars"-like keening is probabl...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: In Massachusetts, Protesters Balk At Pipeline Company's Payments To Police Kinder Morgan has paid st...
# TRUE: Environmental | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: DC's Museum Of African American History Is The City's Greenest The National Museum of African Americ...
# TRUE: Environmental | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Trending LED: Switch Out Your Incandescent and CFLs to LED Light Bulbs To find out what all the LED ...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Amonderez Green, Teen Shot Near Ferguson, Was An Avid Rapper "Sometimes I just feel like I gotta adm...
# TRUE: Legal | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Monsters at the End of a War August 15 was the end of World War II in Asia, 69 years ago, following ...
# TRUE: Political | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Between Threats And Harassment, A Handful Of Hawaii's Giant Telescope Protesters Cross The Line HONO...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Larry Wilmore Clears Up Use Of The N-Word For Confused White People There's a HUGE difference betwee...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Very Few Health Conditions Should Disqualify You From The Presidency Are you alive? Will you be aliv...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Uber Just Took A Huge Step Toward Integrating With Mass Transit Passengers will be able to plan trip...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Slight Drop In Measles Vaccinations Could Triple Infections In U.S. Kids Measles is a highly contagi...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: One Year Later, Arizona Real Estate Investor Still Missing What happened to Sidney Cranston remains ...
# TRUE: Legal | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: This Technology Could Keep Airports From Slaughtering Birds Researchers say they've found an effecti...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Technology, Not Policy, Will Drive Economic Growth President-elect Donald Trump’s economic growth pl...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Food-Themed iPhone Cases For The iPhone 5 And iPhone 4 If there's one thing food lovers are good at ...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: TheFuturein5 Episode 25: Why This Time It's Different As the saying goes, "Either you disrupt or get...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Nonprofits More Chill About Accepting Donations From Pot Companies The stigma is starting to fade....
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Study Predicts Grim Future For Hawaii's Rarest Forest Birds More bad news out of the "extinction cap...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Why I Don't Like Energy-Efficient Light Bulbs I'm a big fan of saving energy: I go shopping with my ...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Country Music Singer Disappears After Ominous Tweet Backroad Anthem singer Craig Strickland and frie...
# TRUE: Legal | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: The Worst Things You Monsters Are Eating On Public Transportation Don't be one of these monsters!...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Ryan Lochte Is Promoting A Device 'That Can Get You Out Of A Bad Situation' The swimmer posted a Twi...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Pokemon Go Players Robbed At Gunpoint, Police Say Be careful out there....
# TRUE: Legal | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Sprout Home Plant Of The Week: Chinese Lantern Fall is officially here....
# TRUE: Social | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Andrew Anglin's Lawyer Visited The Elusive Nazi’s Hometown And Madness Ensued A zany search for Angl...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Oceanographers from U.S. and German GEOTRACES Meet in the High Arctic Ninety five percent of Earth's...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Virginia Task Force Says Liquor Agents Should Be Able To Make Arrests, Despite Screwing Up Multiple ...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: How Wearable Technology Will Change Social Media The ways we use a smart watch (or other wearable de...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Women's March Was The Second-Busiest Day In History Of Washington, D.C., Metro The first was Barack ...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Privatization Has Been a Colossal Flop We have to face the fact that our massive privatization of wh...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Avocado Consumption Booming Thanks To NAFTA Over the course of the aughts, some parts of the United ...
# TRUE: Economic | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: STEM Learning STEMs from Transitions It's Friday as I write and brutally cold out there. As usual, I...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: A Thanksgiving Blessing For All Living Things Divine Spirit, Blessed Ones,/ who guide us throughout ...
# TRUE: Environmental | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: 'Affluenza' Teen Ethan Couch: What Happened? What's Next? Here's a look at what has happened so far ...
# TRUE: Legal | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: The (Mismatched) Evolution of Man and Its Influence on Injury The fundamental ethos of natural selec...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Dozens Of Endangered Seals Wash Up Dead, Starving On California Beaches The threatened Guadalupe fur...
# TRUE: Political | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: How Exxon Mobil And Koch Brothers Created A Culture Of Climate Doubt A new study finds that groups f...
# TRUE: Economic | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Chuck Schumer Just Called Out The FDA's Major Food Safety Problem Delays in our current process put ...
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: There's No Business Like the Waste Business In 2010, Water For People set out to support small scale...
# TRUE: Environmental | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Woman Jumps Off Motorcycle To Rescue Kitty From Oncoming Traffic "Jesus Christ, come on," an impatie...
# TRUE: Environmental | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: When The Womb Is A Crime Scene Alabama has turned hundreds of pregnant women into felons for using d...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: The World’s Largest McDonald’s Franchisee Is Going Totally Cage-Free Millions of animals will no lon...
# TRUE: Economic | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Elon Musk Biographer Calls Wall Street Cynicism 'Depressing And Ignorant' Tesla, SolarCity and Space...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: This Is Mark Zuckerberg's Most Important Meeting Right Now Finally, a CEO shows the world what reall...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Plantations, Prisons And Profits “Louisiana is the world’s prison capital. The state imprisons more ...
# TRUE: Legal | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: 9 Samsung Execs Are Being Investigated For Insider Trading They reportedly purchased $43 million of ...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Trump's Monumental Betrayal Do I really need to list all the reasons why attacking our national monu...
# TRUE: Environmental | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Scott Pruitt Goes After Critics, EPA In His First Speech To The Agency The new EPA administrator mad...
# TRUE: Political | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Low Prices a Problem? Making Sense of Misleading Talk About Cap-and-Trade in Europe and the USA Sinc...
# TRUE: Environmental | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Stanley Fish on Academic Freedom Interested in academic freedom?  If so, you should read Stanley Fis...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Brown University's Misguided Vote to Not Divest From Coal Today, on the anniversary of Hurricane San...
# TRUE: Environmental | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Coast Guard Ends Search For Missing Cargo Ship So far, the body of only one presumed crew member has...
# TRUE: Environmental | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Letter Reveals Drug Courts Lobbied Against Key Addiction Treatment The group didn't want HHS to incr...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Facebook's War Continues Against Fake Profiles and Bots While these accounts were deleted by Faceboo...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Oil And Gas Industry Has Pumped Millions Into Republican Campaigns About one in three dollars donate...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Claiming My Mamahood After My Abortion We may know we made the best decision for our families and ou...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Beer Companies Say Trump’s Aluminum Tariff Will Raise Prices And Hurt The Industry Bad news for beer...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Revisiting the 'Hormone of Love' It's been more than a decade since oxytocin was first heralded as t...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Getting Down and Dirty With Big Healthcare Data Humans are fallible. Humans entering data into healt...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Are You as Secure as a Fourth Grader? (Hint: No) So if you think your government, the TSA, Homeland ...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Vatican Arrests Its Own Diplomat After Child Pornography Probe Monsignor Carlo Alberto Capella was f...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Organizing Expert Brooks Palmer Tells Us To Just Let Go Of Clutter You'll be happy you did it....
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: My Husband is Right: You Can't Trust Online Reviews Not only did my undercover work fail to provide ...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Problems Of The Super Rich Based on recent economic developments, the super rich don’t have much to ...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Raining Spiders In Brazil? Video Appears To Show Numerous Arachnids Dangling Arachnophobes would be ...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: What Silicon Valley Executives Keep Getting Wrong About Education Successful Silicon Valley entrepre...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: 45 U.S. Trade Groups Beg Trump: Don't Impose Tariffs On China The organizations say such tariffs wou...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: GOP Candidates Bound to Feel 'Climate Shock' on the  Campaign Trail Being the next president also me...
# TRUE: Environmental | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Invasive Species Aren’t Always Unwanted A growing number of scientists are challenging this view....
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: The Waiting Is the Hardest Part: Big Business Wins Again If you believe in the minimum wage, then yo...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Boaty McBoatface Is Preparing For Its First Antarctic Mission What, you thought it was all just a jo...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Breast Cancer And Dogs: The Next 'Canaries In The Coal Mine'? Mandi died less than a month later fro...
# TRUE: Environmental | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Vinland Restaurant In Portland, Maine Takes 'Local' To A New Level The chef sees himself as part of ...
# TRUE: Environmental | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: MLK Day 2013: A Look Back At Civil Rights Style (PHOTOS) While we're glued to the Inauguration Day c...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: This Salamander Is Thought To Be The Longest On Earth Karlo lives at Prague Zoo in the Czech Republi...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: CNN: Email Reveals Former District Attorney Agreed Not To Use Civil Deposition Against Cosby (CNN) -...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Welcome To The Class War Financial capital is people, my friend....
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: FBI Reportedly Investigating Clinton Foundation A spokesman for Hillary Clinton called the probe "a ...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Kitten With Multiple Puncture Wounds Miraculously Survives No one can say for certain how the first ...
# TRUE: Environmental | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Creating a Chemically-Free Home Is Easier and Cheaper Than You Think Have you noticed how laboratory...
# TRUE: Environmental | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Uber Sacks Driver After Passenger Records Vile Homophobic Rant An Uber driver has been removed from ...
# TRUE: Economic | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Theranos Is Subject Of Criminal Probe By U.S. Federal prosecutors are investigating whether the bloo...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# ...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Mindsets and Diversity: We All Have Mindsets! What is a "mindset"? How are mindsets related to gende...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Reddit Just Banned Bullying, 'Anything Illegal' Prepare for the backlash....
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Comcast To Acquire DreamWorks Animation For $3.8 Billion The studio behind "Shrek," "Madagascar," an...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Small Changes In Temperature Matter — Probably More Than You Think A recent episode of the Sam Harri...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: SeaWorld Doesn't Seem To Understand Its Business Is Over The world now knows wild animals should sta...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: What the Straight World Learned From the Stonewall Riots (It Was Indeed "a Flash at Midnight") Ultim...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: News Roundup for July 17, 2017 It’s the news, whether you like it or not. 1. “Doctor Who” finally go...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: How Utility Companies Use Charitable Giving To Influence Policy The nation’s 10 largest utilities sp...
# TRUE: Environmental | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: The Major Problem With Electric Cars | TIME.com The model is now the cheapest EV on the market, yet ...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Fix the Gas Tax Before Exploring Per-Mile Taxes Some lawmakers are beginning to wonder whether we ne...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Apple, Amazon, YouTube Urged To Pull NRA TV Channel “It’s time for tech leaders to acknowledge their...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Melting Ice Sheets Changing The Way The Earth Wobbles On Its Axis, Says Nasa Global warming is chang...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Almost 1 Million Immigrant Youths Are Realizing The American Dream. Don't Steal It From Them, Trump....
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: The Big Ask: Closing Gender Pay Gap For Creative Work Starts With Pricing It’s not better working on...
# TRUE: Social | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Independence Day: Facing Fears of Violence I head over to the Arthur Fiedler Footbridge, but it's cl...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Baltimore Cop's Defense: It Wasn’t Safe To Buckle Freddie Gray’s Seatbelt Although a department rule...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Mother And Calf Of Elusive Whale Species Frolic In New Video The whales were only identified as a di...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Yahoo, Third Point Square Off For Proxy Fight Despite Three New Independent Board Directors "The boa...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Do What You Love, But Don't Get Sick I talked to quite a few independent artists who told me about h...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: World's Atmospheric CO2 Spiked To A Record Last Year: UN "Wake up world. We are killing our planet."...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Babies Die; Hospital Halts Heart Surgeries (CNN) -- Tabitha and Lucas Rainey were beginning to get s...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: EPA Quietly Asked The Public Which Clean Air Rules To Cut. Industry Answered Loudest. How many worki...
# TRUE: Political | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Aaron Swartz Suicide: Reddit Co-Founder Dead At 26 Aaron accomplished some incredible things in his ...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: FBI Director Continues Blaming 'Viral Videos' For Murder Spike In Some Cities But James Comey admits...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Why Venmo, And Every App Like It, Is So Annoying To Use There's really no way to make moving money f...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Guy In Trump Hat and 'Deplorables' T-Shirt Arrested At Texas Polling Place “He wanted to take a stan...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Crude Oil Train Derails In Montana An oil train derailed Thursday in rural northeastern Montana, pro...
# TRUE: Economic | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: A 'Ring Of Fire' Eclipse Will Blaze Across The Sky This Week An annular solar eclipse will dazzle vi...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Saudi Prince Who Owns Much Of Twitter Sees IPO By Early 2014 By Mirna Sleiman But the prince said: "...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: DOJ's Chicago Probe Could Expose How We Fail To Punish Bad Cops Investigators will likely focus on a...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Want Green Grass The Easy Way? Follow These 4 Low-Maintenance Summer Lawn Care Tips There's nothing ...
# TRUE: Social | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: We Might Be All Wrong About Robots Taking Our Jobs "It’s true that robots are taking away some jobs,...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: When Is It Okay To Mine Hacked Emails? By Steven Levy for Backchannel. On June 17, 1972, Washington,...
# TRUE: Technological | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Boy Takes Home Top Prize In Competition For Girls In STEM Pretty Curious, a U.K. program aimed at ge...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Jane Goodall Says SeaWorld 'Should Be Closed Down' “It’s not only that they’re really big, highly in...
# TRUE: Economic | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Asian Americans versus Asian Americans Asian immigrants are disappointed Asian Americans are not mor...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: The Drunkest Cities In America Alcohol poisoning and alcohol-related liver diseases are major contri...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Prince Charles and Robert Redford Together for the World Premiere Screening of Harmony As we write f...
# TRUE: Environmental | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: The Politics Of Tax Reform Are Driving Republicans, Not The Policy Just how badly does Corporate Ame...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: These Stock Photos Show Masculinity Is More Than Biceps And Beer Discarding gender stereotypes, new ...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Here's Why Smelling Cookies Makes You Think Of Grandma's House So how can specific scents make you r...
# TRUE: Technological | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Elaborate 'Dead Whale' Stunt Takes Parisians By Surprise There was fortunately a good reason behind ...
# TRUE: Environmental | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Shaky Dams Are Just The Start; 56,000 Bridges Are Also In Trouble Aging spans cover the nation as de...
# TRUE: Technological | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: U.S. Is Building Criminal Cases in Rate-Fixing As regulators ramp up their global investigation into...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Coronavirus Tore Through This Meatpacking Plant With Incredible Speed About 67 Smithfield workers a ...
# TRUE: Economic | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Curate or Be Curated: The Coming Age of the Curation Economy The cure for information overload is co...
# TRUE: Technological | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Texas Hot Air Balloon Crash Kills 16 It is one of the worst such accidents on record....
# TRUE: Legal | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Sisters Kicked Off Flight Say They Missed Their Father's Death "I was saying, ‘Could you please let ...
# TRUE: Legal | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Standing Rock Member Reminds Barack Obama About Promise He Made When They Met “You said, ‘Let’s not ...
# TRUE: Political | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Obamacare Deadline Is A Moving Target At This Point By Susan Cornwell The Affordable Care Act requir...
# TRUE: Economic | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Parkland Students: 'We're The Mass Shooting Generation' Five survivors of the Florida school massacr...
# TRUE: Political | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: 9 Inspiring Animals That Use Prosthetics Prosthetics have changed the lives of disabled and handicap...
# TRUE: Environmental | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Al Gore Takes On Trump On 'Provable Idiocy' “When President Trump made his speech withdrawing the U....
# TRUE: Environmental | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: 4 Tips for Better (And Less Biased) Interview Questions The answer to the question should be relevan...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Keevan Dinkel, Alaska Boy, Wins Annual Cabbage Contest PALMER, Alaska (Reuters) - A 10-year-old boy ...
# TRUE: Environmental | PREDICTED: Social
# --------------------------------------------------------------------------------
# TEXT: Congrats Montana. What's Next - Slapping Babies? Well there it is, America. Greg Gianforte has won t...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: 'Slap in the Face' for Donald Trump to Host SNL, Says Latino Group "This is not about lacking a sens...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Nine Major Ways Criminals Use Facebook Internet security analysts warn that Facebook is a hotbed for...
# TRUE: Economic | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: The Man Beaten And Choked At A Donald Trump Rally Tells His Story When activist Mercutio Southall Jr...
# TRUE: Social | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: Flint Residents May Have Been Drinking Other Dangerous Chemicals RESIDENTS OF FLINT, MICHIGAN, who d...
# TRUE: Political | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Would-Be Cheaters Reveal Their Deepest Secrets On Whisper App Are you thinking of cheating? You're n...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: What is an Alarm Duress Code? Ever consider the idea that a home intruder may force you to turn off ...
# TRUE: Legal | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Ant Problem? Find Out If These 9 Weird Ways To Get Rid Of Ants Actually Work (PHOTOS) Find out what ...
# TRUE: Social | PREDICTED: Technological
# --------------------------------------------------------------------------------
# TEXT: Gator Attack: Disney Knew Of Problems, Staffer Asked For Fence At Lagoon Resort had ongoing concerns...
# TRUE: Legal | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: "This Year We Will Have Hunger:" Fears of Food Shortages in Southern Africa After Floods While the f...
# TRUE: Social | PREDICTED: Environmental
# --------------------------------------------------------------------------------
# TEXT: Rewriting NAFTA Has Serious Implications Beyond Just Trade By Jessica Trisko Darden, American Univer...
# TRUE: Political | PREDICTED: Economic
# --------------------------------------------------------------------------------
# TEXT: Officer Involved In El Cajon Shooting Had Been Sued, Demoted For Sexual Harassment El Cajon Mayor Bi...
# TRUE: Social | PREDICTED: Legal
# --------------------------------------------------------------------------------
# TEXT: Glenn Greenwald Questions If Chattanooga Shooting Was Terrorism And if so, is the U.S. government gu...
# TRUE: Legal | PREDICTED: Political
# --------------------------------------------------------------------------------
# TEXT: You Can't Get Chipotle For Lunch Today *stomach growls*...
# TRUE: Economic | PREDICTED: Social
# --------------------------------------------------------------------------------
